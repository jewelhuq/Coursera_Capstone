# %% [markdown]
# <h1>Background</h1>

# %% [markdown]
# Starting a new business is always challenging and it depends on differnent  criteria. Specially, Venue/Place work as a  vital. Before starting business, business owner should know  about the negighourhood places very well. Plus what kind of business is currently doing well in that particular area also helps in starting a new business

# %% [markdown]
# <h1>Problem Statement
# </h1>

# %% [markdown]
# One of uncle is planning to start a software firm near York,Canada. He is looking for a area or neighbourhood near york which have the following facility:- Gym, Different food and source of young talent who can work for my uncle's company.

# %% [markdown]
# <h1>Data</h1>

# %% [markdown]
# <ul>
#     <li>Foursqare Api </li>
#     <li>Geospatial_Coordinates.csv  - For zipcode mapping</li>
#     <li>Wikipedia - To scrap neighbour Data</li>
# </ul>
#
# <p>
#     <b>Following specific data points will be used for analysis:</b>
#     <li>1. Venues data: will be taken using Foursquare api</li>
#     <li>2. Neighbourhood data: Neighbourhoods,Zipcode and City Name</li>
#     <li>3. Location data: Longitude and lattitude will be taken from Foursqare as </li>
